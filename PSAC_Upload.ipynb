# %% [markdown]
# # PSAC 서버에 데이터 옮기기
# - 내가 갖고 있는 1000개의 Validation Data를 파싱해서 PSAC 서버에 업로드해야한다.
# - C# WPF에서 PSAC 서버에 요청을 해서 데이터를 불러오게 할 것이다.

# %%
import joblib

data = joblib.load('Validation_Data.pkl')
data.head()
# Out:
#    Class                                            Caption  ImageWidth  \
# 0      1  This plain abdominal supine radiograph shows m...         512
# 1      1  This supine plain abdominal radiograph shows m...         512
# 2      1  This plain abdominal supine radiograph of an a...         512
# 3      1  This plain supine abdominal radiograph of an a...         512
# 4      1  This plain supine abdominal radiograph shows m...         512
#
#    ImageHeight  Age                                          ImageFile  \
# 0          512    5  ../Data/Validation/01.원천데이터/VS_1.질환_1.선천성유문협착증...
# 1          512    6  ../Data/Validation/01.원천데이터/VS_1.질환_1.선천성유문협착증...
# 2          512    6  ../Data/Validation/01.원천데이터/VS_1.질환_1.선천성유문협착증...
# 3          512    7  ../Data/Validation/01.원천데이터/VS_1.질환_1.선천성유문협착증...
# 4          512    3  ../Data/Validation/01.원천데이터/VS_1.질환_1.선천성유문협착증...
#
#   PatientName
# 0         이태민
# 1         강호수
# 2         강호민
# 3         최경태
# 4         임도선

# %% [markdown]
# # DataFrame to DICOM

# %%
import os
import uuid
import datetime
import numpy as np
from PIL import Image
import pydicom
from pydicom.dataset import Dataset, FileDataset

def png_to_color_dicom(row, save_path):
    img = Image.open(row['ImageFile']).convert('RGB')
    pixel_array = np.array(img)

    file_meta = pydicom.Dataset()
    file_meta.MediaStorageSOPClassUID = pydicom.uid.SecondaryCaptureImageStorage
    file_meta.MediaStorageSOPInstanceUID = pydicom.uid.generate_uid()
    file_meta.ImplementationClassUID = pydicom.uid.PYDICOM_IMPLEMENTATION_UID

    ds = FileDataset(save_path, {}, file_meta=file_meta, preamble=b"\0" * 128)

    # 필수 태그 추가
    ds.StudyInstanceUID = pydicom.uid.generate_uid()
    ds.SeriesInstanceUID = pydicom.uid.generate_uid()
    ds.SOPInstanceUID = file_meta.MediaStorageSOPInstanceUID
    ds.SOPClassUID = file_meta.MediaStorageSOPClassUID

    ds.Modality = 'OT'
    ds.Rows, ds.Columns = pixel_array.shape[:2]
    ds.PatientAge = f"{int(row['Age']):03}Y"
    ds.StudyDate = datetime.date.today().strftime('%Y%m%d')

    ds.SpecificCharacterSet = 'ISO_IR 192'  # UTF-8 한글 지원
    ds.PatientName = str(row.get('PatientName', f"Patient_{uuid.uuid4()}"))
    ds.PatientID = str(row.get('PatientID', f"ID_{uuid.uuid4()}"))

    ds.SamplesPerPixel = 3
    ds.PhotometricInterpretation = "RGB"
    ds.PlanarConfiguration = 0
    ds.BitsAllocated = 8
    ds.BitsStored = 8
    ds.HighBit = 7
    ds.PixelRepresentation = 0

    ds.PixelData = pixel_array.tobytes()
    ds.save_as(save_path)



def convert_dataframe_to_dicom(df, output_dir):
    """
    DataFrame 전체를 순회하며
    각 행을 DICOM 파일로 저장하는 함수
    """
    os.makedirs(output_dir, exist_ok=True)

    for idx, row in df.iterrows():
        dicom_path = os.path.join(output_dir, f"image_{idx:04d}.dcm")
        png_to_color_dicom(row, dicom_path)


# 예시로 df가 이미 로드되어 있다고 가정
# df = pd.read_csv('your_csv_or_other_source.csv')

# 출력 폴더 설정
output_folder = './dicom_output'

# 변환 실행
convert_dataframe_to_dicom(data, output_folder)

# %%
ds = pydicom.dcmread("dicom_output\image_0001.dcm")
print(ds)  # DICOM 메타데이터 전체 출력
# Out:
# Dataset.file_meta -------------------------------
# (0002,0002) Media Storage SOP Class UID         UI: Secondary Capture Image Storage
# (0002,0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.8.498.73714185418037749128523977475146727289
# (0002,0012) Implementation Class UID            UI: 1.2.826.0.1.3680043.8.498.1
# -------------------------------------------------
# (0008,0005) Specific Character Set              CS: 'ISO_IR 192'
# (0008,0016) SOP Class UID                       UI: Secondary Capture Image Storage
# (0008,0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.8.498.73714185418037749128523977475146727289
# (0008,0020) Study Date                          DA: '20250708'
# (0008,0060) Modality                            CS: 'OT'
# (0008,103E) Series Description                  LO: 'This supine plain abdominal radiograph shows markedly distended stomach.'
# (0010,0010) Patient's Name                      PN: '강호수'
# (0010,0020) Patient ID                          LO: 'ID_f8c90984-e2ab-4745-940e-a319cc60c0c2'
# (0010,1010) Patient's Age                       AS: '006Y'
# (0020,000D) Study Instance UID                  UI: 1.2.826.0.1.3680043.8.498.90067147942721252520617442974860573233
# (0020,000E) Series Instance UID                 UI: 1.2.826.0.1.3680043.8.498.83114081341688129652189785214042529464
# (0028,0002) Samples per Pixel                   US: 3
# (0028,0004) Photometric Interpretation          CS: 'RGB'
# (0028,0006) Planar Configuration                US: 0
# (0028,0010) Rows                                US: 512
# (0028,0011) Columns                             US: 512
# (0028,0100) Bits Allocated                      US: 8
# (0028,0101) Bits Stored                         US: 8
# (0028,0102) High Bit                            US: 7
# (0028,0103) Pixel Representation                US: 0
# (7FE0,0010) Pixel Data                          OW: Array of 786432 elements

# %% [markdown]
# # PSAC 서버에 업로딩 성공 (Validation Image data 1000개)

# %%
# import requests
# import json

# # Orthanc 서버 정보
# ORTHANC_URL = "http://localhost:8042"  # 또는 http://your.server.ip:8042
# AUTH = ("orthanc", "orthanc")  # 기본값

# # 1. 환자 목록 가져오기
# patients_url = f"{ORTHANC_URL}/patients"
# response = requests.get(patients_url, auth=AUTH)

# patient_ids = response.json()
# print("환자 수:", len(patient_ids))

# # 2. 각 환자별 정보 조회
# for patient_id in patient_ids:
#     patient_info_url = f"{ORTHANC_URL}/patients/{patient_id}"
#     patient_info = requests.get(patient_info_url, auth=AUTH).json()

#     print(f"\n[환자 이름] {patient_info.get('MainDicomTags', {}).get('PatientName')}")
#     print(f"Study 수: {len(patient_info.get('Studies', []))}")

#     # 3. Study → Series → Instance 순으로 접근
#     for study_id in patient_info['Studies']:
#         study_url = f"{ORTHANC_URL}/studies/{study_id}"
#         study_info = requests.get(study_url, auth=AUTH).json()

#         for series_id in study_info['Series']:
#             series_url = f"{ORTHANC_URL}/series/{series_id}"
#             series_info = requests.get(series_url, auth=AUTH).json()

#             for instance_id in series_info['Instances']:
#                 # 이미지 썸네일 가져오기 (예시)
#                 preview_url = f"{ORTHANC_URL}/instances/{instance_id}/preview"
#                 image = requests.get(preview_url, auth=AUTH).content

#                 # 저장해보기
#                 with open(f"DICOM_GET/{instance_id}.jpg", "wb") as f:
#                     f.write(image)
#                 print(f"  ➤ 이미지 저장됨: /{instance_id}.jpg")
# Out:
# 환자 수: 1000
#
# [환자 이름] 이하민
# Study 수: 1
#   ➤ 이미지 저장됨: /07d4e91d-364f4617-388a192f-e84f04a8-5e55c34f.jpg
#
# [환자 이름] 장수선
# Study 수: 1
#   ➤ 이미지 저장됨: /4c7d4a66-03e10a0c-3d4368cd-ec888674-0b1a4c13.jpg
#
# [환자 이름] 윤호민
# Study 수: 1
#   ➤ 이미지 저장됨: /64a69ef2-e55dd7c4-99499399-fcd7bcfd-0010531d.jpg
#
# [환자 이름] 조호선
# Study 수: 1
#   ➤ 이미지 저장됨: /40b3f3c2-2d562a50-7a7f9cfe-4323ea3b-1af8bec8.jpg
#
# [환자 이름] 강선영
# Study 수: 1
#   ➤ 이미지 저장됨: /b5535e10-ff665376-9b053bd3-35e3d61a-4b9ab73c.jpg
#
# [환자 이름] 임태성
# Study 수: 1
#   ➤ 이미지 저장됨: /19a194e4-2be9809a-ab01dc6f-32c13432-f2b44668.jpg
#
# [환자 이름] 이윤호
# Study 수: 1
#   ➤ 이미지 저장됨: /55026d63-a02f3d5d-c0fdc6fc-da547bcf-8aafc947.jpg
#
# [환자 이름] 박현성
# Study 수: 1
#   ➤ 이미지 저장됨: /2a5db231-eb0cef9c-246d431a-cb0f443e-9c05bc97.jpg
#
# [환자 이름] 임하호
# Study 수: 1
#   ➤ 이미지 저장됨: /a177a3b5-ae90b57e-73ae84e7-6f0f3a36-1ada84eb.jpg
#
# [환자 이름] 박민윤
# Study 수: 1
#   ➤ 이미지 저장됨: /e8d3ad03-99fa048b-7499ee63-f3533dad-fc55b00a.jpg
#
# [환자 이름] 이태우
# Study 수: 1
#   ➤ 이미지 저장됨: /b00b9c95-f79a713a-b7854b9a-ec21b090-d671fc41.jpg
#
# [환자 이름] 김성수
# Study 수: 1
#   ➤ 이미지 저장됨: /e054377e-68727403-231f68cc-4f57cdfc-e900e06e.jpg
#
# [환자 이름] 윤태경
# Study 수: 1
#   ➤ 이미지 저장됨: /31dd5494-038bd447-2c377d24-4e787158-4edfd27b.jpg
#
# [환자 이름] 윤민태
# Study 수: 1
#   ➤ 이미지 저장됨: /2481a48c-f3dd35c7-be2fd1dd-af23832e-2035ca4b.jpg
#
# [환자 이름] 조영호
# Study 수: 1
#   ➤ 이미지 저장됨: /d8786e09-7713011d-1aad88fd-ec6e6cfc-19ef3293.jpg
#
# [환자 이름] 박태진
# Study 수: 1
#   ➤ 이미지 저장됨: /3dda6470-1d471085-57dcc27f-9af1d1bd-6ab9d69a.jpg
#
# [환자 이름] 임민영
# Study 수: 1
#   ➤ 이미지 저장됨: /a39d101f-2e40fe62-7029a172-7ccda4e0-87c24a9c.jpg
#
# [환자 이름] 장재서
# Study 수: 1
#   ➤ 이미지 저장됨: /d9e4ca58-1c12259b-75521245-e11ef21c-c872bc6b.jpg
#
# [환자 이름] 이수선
# Study 수: 1
#   ➤ 이미지 저장됨: /1a32e406-caedbdd9-3d423985-3a433267-52e77b9a.jpg
#
# [환자 이름] 김태우
# Study 수: 1
#   ➤ 이미지 저장됨: /69125d54-e99fe7b4-c2a0ceb4-2227131e-b72bba4f.jpg
#
# [환자 이름] 장선경
# Study 수: 1
#   ➤ 이미지 저장됨: /852b2772-5eabe2f6-d4afae35-743f797c-c19d1585.jpg
#
# [환자 이름] 박성수
# Study 수: 1
#   ➤ 이미지 저장됨: /ffea9db4-0d370126-f678e6f2-88766d48-feeadff6.jpg
#
# [환자 이름] 임윤우
# Study 수: 1
#   ➤ 이미지 저장됨: /894ca8b2-f3113eac-1c797c1f-98d83e30-61b794f6.jpg
#
# [환자 이름] 윤도경
# Study 수: 1
#   ➤ 이미지 저장됨: /20cbc421-33d7b4a3-ceb75fc8-c685e8b3-042c7914.jpg
#
# [환자 이름] 임호서
# Study 수: 1
#   ➤ 이미지 저장됨: /631b07a5-1e75316f-414b1973-31e4d005-c05ea396.jpg
#
# [환자 이름] 박윤태
# Study 수: 1
#   ➤ 이미지 저장됨: /a94bc6e3-e658c5ac-77b367f4-43fd5f9c-8e1d2951.jpg
#
# [환자 이름] 임진현
# Study 수: 1
#   ➤ 이미지 저장됨: /93e1b2af-61aaeae8-d84d0956-9148b36e-23e9523e.jpg
#
# [환자 이름] 박선호
# Study 수: 1
#   ➤ 이미지 저장됨: /bac13b71-a686baa5-820b85a7-20e6557c-5865b1f7.jpg
#
# [환자 이름] 장우준
# Study 수: 1
#   ➤ 이미지 저장됨: /9532382f-5561aaf4-ffddbc34-54b7eb97-c8023247.jpg
#
# [환자 이름] 김준민
# Study 수: 1
#   ➤ 이미지 저장됨: /ecd856d8-8fe71e01-6b8c6d36-3671f335-5c948668.jpg
#
# [환자 이름] 윤하현
# Study 수: 1
#   ➤ 이미지 저장됨: /59c18ec5-64a19098-4361e6c5-2e6ca16d-99a2feb9.jpg
#
# [환자 이름] 최진서
# Study 수: 1
#   ➤ 이미지 저장됨: /4341116b-dd9fb39c-b752f434-743f87b8-d2952c21.jpg
#
# [환자 이름] 이하준
# Study 수: 1
#   ➤ 이미지 저장됨: /39c24b86-aebd2999-23dbdedf-80ed5135-b1278094.jpg
#
# [환자 이름] 정진도
# Study 수: 1
#   ➤ 이미지 저장됨: /42645ced-9ec7b5e3-a3893c61-6d704344-5a69df95.jpg
#
# [환자 이름] 강태우
# Study 수: 1
#   ➤ 이미지 저장됨: /02787803-13c9823e-3e3aac47-fcc8f29b-d433c098.jpg
#
# [환자 이름] 김선호
# Study 수: 1
#   ➤ 이미지 저장됨: /abd8019a-5efd342b-e4a7edb1-f57f264d-154db64b.jpg
#
# [환자 이름] 윤도준
# Study 수: 1
#   ➤ 이미지 저장됨: /b6eb9ac5-dcb7d34d-edc4999e-0def2226-3cd46268.jpg
#
# [환자 이름] 조성현
# Study 수: 1
#   ➤ 이미지 저장됨: /059624af-f2754bb2-ba8fce0e-b834d0db-0b09da3c.jpg
#
# [환자 이름] 최도도
# Study 수: 1
#   ➤ 이미지 저장됨: /7fc0a1b5-9559165a-63a05e96-44c1b474-2a28fd92.jpg
#
# [환자 이름] 김호영
# Study 수: 1
#   ➤ 이미지 저장됨: /34915b53-1eae9251-b000da9f-8281f809-ba74ea5f.jpg
#
# [환자 이름] 김호현
# Study 수: 1
#   ➤ 이미지 저장됨: /bf1d26d2-02d91166-0ba75d4e-598a4782-8cacef29.jpg
#
# [환자 이름] 박민호
# Study 수: 1
#   ➤ 이미지 저장됨: /e9cf638b-af6ef477-5fd25dff-01d7096e-1c0ee891.jpg
#
# [환자 이름] 이태민
# Study 수: 1
#   ➤ 이미지 저장됨: /97af1ffa-187b412f-3c1c6c77-43391b69-446c0871.jpg
#
# [환자 이름] 김지선
# Study 수: 1
#   ➤ 이미지 저장됨: /40682256-6d64d4e2-7296e320-ec767f1b-b66f5fab.jpg
#
# [환자 이름] 장선우
# Study 수: 1
#   ➤ 이미지 저장됨: /11f456b6-c12edcec-b48c6c88-b35befe8-ef907f86.jpg
#
# [환자 이름] 김경윤
# Study 수: 1
#   ➤ 이미지 저장됨: /9fc5eb85-53626be4-c289f3f1-b2fe2a75-ecf45053.jpg
#
# [환자 이름] 최호하
# Study 수: 1
#   ➤ 이미지 저장됨: /c1a7419e-49d6a30b-7f91e81f-c8a1a441-e3fdc056.jpg
#
# [환자 이름] 김준태
# Study 수: 1
#   ➤ 이미지 저장됨: /8579a41e-37e54da2-df865864-fad98b91-b461a995.jpg
#
# [환자 이름] 김지우
# Study 수: 1
#   ➤ 이미지 저장됨: /988710d1-a658263f-643a28d9-9ece9d96-d3e7da57.jpg
#
# [환자 이름] 강민선
# Study 수: 1
#   ➤ 이미지 저장됨: /605bd644-30f8e229-463c0bb5-8888a57b-988e510d.jpg
#
# [환자 이름] 장서도
# Study 수: 1
#   ➤ 이미지 저장됨: /78b9c2a8-a669575f-50cfff2c-c51d0617-1d3cea75.jpg
#
# [환자 이름] 김서호
# Study 수: 1
#   ➤ 이미지 저장됨: /5815c557-b722014d-3b73d7e6-256f45e5-175280f9.jpg
#
# [환자 이름] 이민영
# Study 수: 1
#   ➤ 이미지 저장됨: /ede829b5-19f5f3e0-f33f0d38-4cbaeb81-3865bbe1.jpg
#
# [환자 이름] 박호지
# Study 수: 1
#   ➤ 이미지 저장됨: /2e472374-457a79b9-862f0966-f8df87fd-8a46f9c3.jpg
#
# [환자 이름] 조영준
# Study 수: 1
#   ➤ 이미지 저장됨: /b961372b-d3ef2fea-0192bff0-3ab5248a-a944cec6.jpg
#
# [환자 이름] 강서영
# Study 수: 1
#   ➤ 이미지 저장됨: /cb51915c-53b848e1-64fd89a0-feaefcfc-fcd1b07c.jpg
#
# [환자 이름] 강윤경
# Study 수: 1
#   ➤ 이미지 저장됨: /9ee9b053-bf2fc702-8faf325e-7c08aec7-4a696fdf.jpg
#
# [환자 이름] 강준윤
# Study 수: 1
#   ➤ 이미지 저장됨: /2c88bfb7-7e26df3c-355a5488-20bc2a6f-0a85ed33.jpg
#
# [환자 이름] 장재수
# Study 수: 1
#   ➤ 이미지 저장됨: /91b8e747-c9041dbb-6304c39e-f25f55e3-195a4039.jpg
#
# [환자 이름] 박수민
# Study 수: 1
#   ➤ 이미지 저장됨: /9835a5bb-f07acc32-a916555b-b15d814e-46de7d99.jpg
#
# [환자 이름] 정경선
# Study 수: 1
#   ➤ 이미지 저장됨: /e0e3b3bc-2353eab6-1fa42135-a0b3123b-5d1c786f.jpg
#
# [환자 이름] 박진윤
# Study 수: 1
#   ➤ 이미지 저장됨: /80ab9c74-8c287ce2-220316f0-55b2a99a-0742dc3c.jpg
#
# [환자 이름] 정하도
# Study 수: 1
#   ➤ 이미지 저장됨: /4656deba-fff4ea02-285a869f-d18cd3d1-5b7c9e41.jpg
#
# [환자 이름] 김영준
# Study 수: 1
#   ➤ 이미지 저장됨: /90aadb1b-64601d0f-c305b7f6-7ad35e5d-8bf4c83d.jpg
#
# [환자 이름] 최서선
# Study 수: 1
#   ➤ 이미지 저장됨: /ff47897a-7aa108f3-307fe09e-4ecd8157-7df18a2e.jpg
#
# [환자 이름] 김태진
# Study 수: 1
#   ➤ 이미지 저장됨: /0dddd94b-d8edfe4b-387c4dcd-b4a66866-586702ad.jpg
#
# [환자 이름] 장하민
# Study 수: 1
#   ➤ 이미지 저장됨: /28a06d4e-faee8447-dcde67ab-108f3ea2-6c3644b7.jpg
#
# [환자 이름] 조지경
# Study 수: 1
#   ➤ 이미지 저장됨: /883ebf7b-39c1123a-c517e256-f5bfc421-0a382864.jpg
#
# [환자 이름] 장현준
# Study 수: 1
#   ➤ 이미지 저장됨: /e727377d-66a521f1-58632a7c-dbf0cf22-6d7a6467.jpg
#
# [환자 이름] 이호진
# Study 수: 1
#   ➤ 이미지 저장됨: /03e1b980-92a6012e-4ea38055-49117b4b-9437c41e.jpg
#
# [환자 이름] 이도수
# Study 수: 1
#   ➤ 이미지 저장됨: /3c48036d-56fa938e-ab2d85ff-29328267-97e46013.jpg
#
# [환자 이름] 장민선
# Study 수: 1
#   ➤ 이미지 저장됨: /74cc64b0-7e34d6ea-0dc0b15f-2841857b-cb962c83.jpg
#
# [환자 이름] 강현윤
# Study 수: 1
#   ➤ 이미지 저장됨: /055b074a-2bc693e8-271724a3-c0eee391-6d238bd7.jpg
#
# [환자 이름] 임준호
# Study 수: 1
#   ➤ 이미지 저장됨: /3940babf-b9e9f4f8-2da95864-f542fa10-8defdcb2.jpg
#
# [환자 이름] 윤선수
# Study 수: 1
#   ➤ 이미지 저장됨: /6ab610b5-4407d02b-7970bd5e-19d7ff4a-d691efd4.jpg
#
# [환자 이름] 이윤영
# Study 수: 1
#   ➤ 이미지 저장됨: /0efad97c-b161e127-a27c9fca-4ebc0026-2392a55e.jpg
#
# [환자 이름] 박민준
# Study 수: 1
#   ➤ 이미지 저장됨: /78abde2c-779452ae-fcaf1165-ae74ac67-4d223523.jpg
#
# [환자 이름] 윤서우
# Study 수: 1
#   ➤ 이미지 저장됨: /56fc929f-cf3fcf0a-f932a60e-07e19b85-60b5b234.jpg
#
# [환자 이름] 임태현
# Study 수: 1
#   ➤ 이미지 저장됨: /61096841-2d3c75bc-d8614444-9c2362f4-3de15e01.jpg
#
# [환자 이름] 장진준
# Study 수: 1
#   ➤ 이미지 저장됨: /b7ce723a-4d68c54e-d4675119-619463e3-64b7c4f6.jpg
#
# [환자 이름] 임현진
# Study 수: 1
#   ➤ 이미지 저장됨: /f325c910-ec69b05c-d27310bd-b2c96a59-e3a1fe32.jpg
#
# [환자 이름] 윤호수
# Study 수: 1
#   ➤ 이미지 저장됨: /3a2fc5af-c3eebc62-2426df08-5c0b6f7d-0397ad03.jpg
#
# [환자 이름] 김호하
# Study 수: 1
#   ➤ 이미지 저장됨: /412f4865-eb1a032e-601ecc43-b3bda9a4-73287550.jpg
#
# [환자 이름] 조호준
# Study 수: 1
#   ➤ 이미지 저장됨: /ff0f5d54-280a8c48-d4cfa76b-b99b1532-b4f9a8e7.jpg
#
# [환자 이름] 조재지
# Study 수: 1
#   ➤ 이미지 저장됨: /a5c53987-ec87cd21-1f6a1410-9d9f02a4-2e609596.jpg
#
# [환자 이름] 조진재
# Study 수: 1
#   ➤ 이미지 저장됨: /93e35d66-13a21f6d-98396c9e-8ef81315-d3b916bf.jpg
#
# [환자 이름] 임경호
# Study 수: 1
#   ➤ 이미지 저장됨: /fb10f970-af07d257-ba1162d4-f117d97a-48f3a41d.jpg
#
# [환자 이름] 이성지
# Study 수: 1
#   ➤ 이미지 저장됨: /feb1af14-3c629d28-16b5cf3d-e2442f52-17d7c03d.jpg
#
# [환자 이름] 이호호
# Study 수: 1
#   ➤ 이미지 저장됨: /b8083bff-9f4ba3ca-faa5ade3-6feeb71d-ddb9a94f.jpg
#
# [환자 이름] 김우호
# Study 수: 1
#   ➤ 이미지 저장됨: /90a4e863-ec662f0e-9d06bcfa-ab075d29-a1689689.jpg
#
# [환자 이름] 임지성
# Study 수: 1
#   ➤ 이미지 저장됨: /3fddd3fa-0a70e1ea-c60f24b0-756bd360-e1a772c3.jpg
#
# [환자 이름] 이현영
# Study 수: 1
#   ➤ 이미지 저장됨: /bec57b0f-b3a76a41-9e69aad7-1bfcbcd3-f8c48303.jpg
#
# [환자 이름] 김민경
# Study 수: 1
#   ➤ 이미지 저장됨: /ec8d2ef6-4808a742-562118cf-b6b31080-e88a339f.jpg
#
# [환자 이름] 강호수
# Study 수: 1
#   ➤ 이미지 저장됨: /107f9caa-96903dec-078095a3-18b2294b-c54aee5b.jpg
#
# [환자 이름] 이하하
# Study 수: 1
#   ➤ 이미지 저장됨: /a4360181-46763de7-25878057-45ba8195-37f451e1.jpg
#
# [환자 이름] 임성경
# Study 수: 1
#   ➤ 이미지 저장됨: /38a8e02d-f146c14e-87c47b54-6ddf4ad2-e970a350.jpg
#
# [환자 이름] 장현하
# Study 수: 1
#   ➤ 이미지 저장됨: /47e3407a-97047af7-1e9d7882-b13bc034-6be50cfe.jpg
#
# [환자 이름] 윤지지
# Study 수: 1
#   ➤ 이미지 저장됨: /ccae8d21-584a5239-926d9fdc-aeb86d72-66340bdc.jpg
#
# [환자 이름] 임진경
# Study 수: 1
#   ➤ 이미지 저장됨: /77bca2db-1370f74f-90c91290-6512fff6-4788eac5.jpg
#
# [환자 이름] 최선도
# Study 수: 1
#   ➤ 이미지 저장됨: /3456e796-ae1eef40-ee846281-c9a7af71-f0493b43.jpg
#
# [환자 이름] 이지호
# Study 수: 1
#   ➤ 이미지 저장됨: /2cfb7a14-e693a2ad-33131647-2484fc9f-bd2fac3f.jpg
#
# [환자 이름] 최민재
# Study 수: 1
#   ➤ 이미지 저장됨: /a9fda94b-fa5b2562-adb0fa64-38920de4-3377b798.jpg
#
# [환자 이름] 윤서진
# Study 수: 1
#   ➤ 이미지 저장됨: /2c57c556-5a2ebc35-5fc5ee7f-2eb9b165-4519bb73.jpg
#
# [환자 이름] 윤성경
# Study 수: 1
#   ➤ 이미지 저장됨: /b5162c9e-cb57fe94-db4de93a-18e3ee50-c299fa63.jpg
#
# [환자 이름] 윤도호
# Study 수: 1
#   ➤ 이미지 저장됨: /c97b7630-b17d3f3d-c9edbe89-39dfc23e-b3e075a3.jpg
#
# [환자 이름] 최민진
# Study 수: 1
#   ➤ 이미지 저장됨: /3329d0df-0e1df30b-33997a85-c0e9c937-15d01a7a.jpg
#
# [환자 이름] 박재민
# Study 수: 1
#   ➤ 이미지 저장됨: /cd2babf0-cf7e90d5-731c0315-e18891b1-5909fe91.jpg
#
# [환자 이름] 이경태
# Study 수: 1
#   ➤ 이미지 저장됨: /c691dd20-c7fb60a2-bd0b0238-025a009c-3f0ba38b.jpg
#
# [환자 이름] 장재준
# Study 수: 1
#   ➤ 이미지 저장됨: /faf3f14d-f960ce7e-9a0cc897-71ea9615-db993a59.jpg
#
# [환자 이름] 윤준영
# Study 수: 1
#   ➤ 이미지 저장됨: /3745040c-93636d2b-96801e79-3554159d-aa6fed53.jpg
#
# [환자 이름] 정호도
# Study 수: 1
#   ➤ 이미지 저장됨: /bd40946a-9ced9560-aaba28c7-31a610a8-15fd6f21.jpg
#
# [환자 이름] 장민서
# Study 수: 1
#   ➤ 이미지 저장됨: /60db88a9-e3e27a4e-1ae3bd2e-3031d164-c96d3495.jpg
#
# [환자 이름] 이호태
# Study 수: 1
#   ➤ 이미지 저장됨: /3f6eb168-10fd96a4-30721386-a00a093d-3ca4f7d0.jpg
#
# [환자 이름] 강호재
# Study 수: 1
#   ➤ 이미지 저장됨: /3d53c7c2-0f7f3afd-188f6ae5-6d3a45de-afdf37b6.jpg
#
# [환자 이름] 임선서
# Study 수: 1
#   ➤ 이미지 저장됨: /57967cb0-15a4b135-9be2e3dd-8ea30df6-42a5a8f6.jpg
#
# [환자 이름] 최수호
# Study 수: 1
#   ➤ 이미지 저장됨: /7c5c2dd6-37b70692-61bfde78-88abbb70-fd98d6d4.jpg
#
# [환자 이름] 장준선
# Study 수: 1
#   ➤ 이미지 저장됨: /26f2e842-919cf1a5-d466c957-a31ed669-6e87f577.jpg
#
# [환자 이름] 김경영
# Study 수: 1
#   ➤ 이미지 저장됨: /e6ad28fa-ba971a50-17d3fa95-aef64d84-870217bf.jpg
#
# [환자 이름] 임하재
# Study 수: 1
#   ➤ 이미지 저장됨: /6d6ea9ac-03fe994b-4e9fc74c-1e994522-b948158b.jpg
#
# [환자 이름] 장호우
# Study 수: 1
#   ➤ 이미지 저장됨: /1ecc6a61-d1b10beb-aa5b382b-d1d49ac9-5ba9e575.jpg
#
# [환자 이름] 강준호
# Study 수: 1
#   ➤ 이미지 저장됨: /8ddc1a80-c7dbb3bd-edf7339b-97f25f1a-8ce1008a.jpg
#
# [환자 이름] 최현진
# Study 수: 1
#   ➤ 이미지 저장됨: /74943938-ba8ef587-3550fe19-86944945-af4f71ea.jpg
#
# [환자 이름] 윤재성
# Study 수: 1
#   ➤ 이미지 저장됨: /d88f5304-3b1824b7-07215e88-323c4265-d3b978ea.jpg
#
# [환자 이름] 김호도
# Study 수: 1
#   ➤ 이미지 저장됨: /11530090-31c260dc-98e2f9b7-b2c0fbc6-05a47280.jpg
#
# [환자 이름] 이성태
# Study 수: 1
#   ➤ 이미지 저장됨: /ac73ecb3-1189b3ed-d2249ce0-504e0f05-516d3b9c.jpg
#
# [환자 이름] 윤태진
# Study 수: 1
#   ➤ 이미지 저장됨: /8adba6f8-efd31b59-7694a3d9-6afccea3-5d8fe0d7.jpg
#
# [환자 이름] 김영태
# Study 수: 1
#   ➤ 이미지 저장됨: /b28aae07-2ec7c401-3b223119-5bda98e9-11b5fd09.jpg
#
# [환자 이름] 박도태
# Study 수: 1
#   ➤ 이미지 저장됨: /3769c9b0-46f2fa21-1c701cb3-5825300c-6194bb8b.jpg
#
# [환자 이름] 장호경
# Study 수: 1
#   ➤ 이미지 저장됨: /f0cba22d-2e9773f7-9e0528da-f09c5bcc-4e03a543.jpg
#
# [환자 이름] 장민성
# Study 수: 1
#   ➤ 이미지 저장됨: /db05ec26-80f6ac4a-76363695-abea6ee8-ebe1e89a.jpg
#
# [환자 이름] 최태호
# Study 수: 1
#   ➤ 이미지 저장됨: /9caa100d-dbaed14d-9ff3b245-47392bd7-f34ace77.jpg
#
# [환자 이름] 김호성
# Study 수: 1
#   ➤ 이미지 저장됨: /9771b1e1-ffdb16a5-c179a1f3-368dbcff-0247aaf7.jpg
#
# [환자 이름] 최서민
# Study 수: 1
#   ➤ 이미지 저장됨: /aa60f043-f8946d85-b079488d-b9e80903-1faac0a9.jpg
#
# [환자 이름] 박호현
# Study 수: 1
#   ➤ 이미지 저장됨: /7ea3a49f-cc2a30b4-7595b584-1bd5e437-f11b2c11.jpg
#
# [환자 이름] 장지영
# Study 수: 1
#   ➤ 이미지 저장됨: /801682fa-0ec4b041-1202d7a5-ec0e49b0-23d1fe37.jpg
#
# [환자 이름] 이지준
# Study 수: 1
#   ➤ 이미지 저장됨: /bc5e2b7b-2d9872bf-f05feb84-209ce8b3-f77a92ca.jpg
#
# [환자 이름] 임태선
# Study 수: 1
#   ➤ 이미지 저장됨: /ffcc47fd-1a3c3ece-1750859c-c63a79cc-f286884b.jpg
#
# [환자 이름] 장경성
# Study 수: 1
#   ➤ 이미지 저장됨: /76dbffc6-562baf91-87c79d9c-ea028e40-ac9195a9.jpg
#
# [환자 이름] 조현재
# Study 수: 1
#   ➤ 이미지 저장됨: /5033df44-7205de7c-dc0ea4f0-e7910c12-1da26fcb.jpg
#
# [환자 이름] 강윤우
# Study 수: 1
#   ➤ 이미지 저장됨: /389ed290-cbf50399-4c9028bb-f74084e9-8bab2f42.jpg
#
# [환자 이름] 윤경지
# Study 수: 1
#   ➤ 이미지 저장됨: /0ac7bb82-14f85033-dfd7d8fa-81f4e040-d8d36a0a.jpg
#
# [환자 이름] 최도준
# Study 수: 1
#   ➤ 이미지 저장됨: /7934450a-4f16f1de-84334c4b-8193d79f-7d7ccd00.jpg
#
# [환자 이름] 장준하
# Study 수: 1
#   ➤ 이미지 저장됨: /203a786f-2c043a10-bc1cd944-9eece553-2a5b25e4.jpg
#
# [환자 이름] 김현선
# Study 수: 1
#   ➤ 이미지 저장됨: /f3f2e1bd-ca573d55-e75b3a33-7d884518-1556f38f.jpg
#
# [환자 이름] 정진호
# Study 수: 1
#   ➤ 이미지 저장됨: /41e59e01-8cf56bd7-ed37c164-f15de085-b6a1cb16.jpg
#
# [환자 이름] 박우준
# Study 수: 1
#   ➤ 이미지 저장됨: /8629ed97-9d8907e0-94a6278b-9a960d3e-cc0c2340.jpg
#
# [환자 이름] 이서준
# Study 수: 1
#   ➤ 이미지 저장됨: /e955e77e-7fea82a7-094caa6e-2b4fcb91-58594ad9.jpg
#
# [환자 이름] 최재영
# Study 수: 1
#   ➤ 이미지 저장됨: /55b9c90e-d7007676-268e1fe8-ae208cc4-781c6a2f.jpg
#
# [환자 이름] 장지성
# Study 수: 1
#   ➤ 이미지 저장됨: /a92000cd-21277c3d-25f9ec94-685d8319-4bc8ea70.jpg
#
# [환자 이름] 정진경
# Study 수: 1
#   ➤ 이미지 저장됨: /89d78cb9-d34ff727-fcd010c2-462f2a55-d91e611e.jpg
#
# [환자 이름] 장호하
# Study 수: 1
#   ➤ 이미지 저장됨: /aa30a1cd-0a9a6528-c4ffe753-c324f7c7-d184d8c4.jpg
#
# [환자 이름] 최도우
# Study 수: 1
#   ➤ 이미지 저장됨: /1a059ca5-e846b880-438e071d-0ff8b3b6-37a6844b.jpg
#
# [환자 이름] 윤호호
# Study 수: 1
#   ➤ 이미지 저장됨: /dee26973-7781e117-9b1aaf02-8c1bfc10-542a69ea.jpg
#
# [환자 이름] 강수현
# Study 수: 1
#   ➤ 이미지 저장됨: /8416e0ed-23d6e965-a9abcabd-81103f3e-c40d13af.jpg
#
# [환자 이름] 장호호
# Study 수: 1
#   ➤ 이미지 저장됨: /dc989372-67f73cb4-3c6d927f-4d242d2a-e92b1c00.jpg
#
# [환자 이름] 임민재
# Study 수: 1
#   ➤ 이미지 저장됨: /973de4b8-3d315fce-29d35fc1-dce5e0c6-0a31509c.jpg
#
# [환자 이름] 임호현
# Study 수: 1
#   ➤ 이미지 저장됨: /8fe78ceb-a414cc37-b9f882a6-7a1e0d6f-967bdb08.jpg
#
# [환자 이름] 임진서
# Study 수: 1
#   ➤ 이미지 저장됨: /8fff8244-db82fe98-e13bf3f2-5f571b9d-09e9ff35.jpg
#
# [환자 이름] 정경민
# Study 수: 1
#   ➤ 이미지 저장됨: /ff15f676-a470b624-a5a7dcb3-86ef0532-3efcb294.jpg
#
# [환자 이름] 윤진진
# Study 수: 1
#   ➤ 이미지 저장됨: /61e83bc3-b62252c2-5b3f866b-0cf7cb94-2fa9ce7c.jpg
#
# [환자 이름] 이진영
# Study 수: 1
#   ➤ 이미지 저장됨: /35bd646c-2ff3dc44-bf187474-21a454dc-0dc9c537.jpg
#
# [환자 이름] 이수성
# Study 수: 1
#   ➤ 이미지 저장됨: /775858bd-e8885371-d7613df6-d8d8a57e-34bbcc76.jpg
#
# [환자 이름] 최호도
# Study 수: 1
#   ➤ 이미지 저장됨: /c3b5375a-09a4268c-c34781eb-d610137b-5899bb6c.jpg
#
# [환자 이름] 정호하
# Study 수: 1
#   ➤ 이미지 저장됨: /dec76d9e-b228f0c2-aaf63721-9460e3f5-c56323e2.jpg
#
# [환자 이름] 장지하
# Study 수: 1
#   ➤ 이미지 저장됨: /21ac33a7-1c1f50ba-4d754d98-a91db13e-2013089e.jpg
#
# [환자 이름] 정윤재
# Study 수: 1
#   ➤ 이미지 저장됨: /5a224b2a-ec4f20c0-e728e1bf-13b19939-adfdee9d.jpg
#
# [환자 이름] 강윤성
# Study 수: 1
#   ➤ 이미지 저장됨: /b3362a9c-c2a33f27-11e0ef3a-b119e410-accf09a6.jpg
#
# [환자 이름] 김도하
# Study 수: 1
#   ➤ 이미지 저장됨: /255bf157-f8f92246-52a968d7-1bfc6a01-ee9adadf.jpg
#
# [환자 이름] 조하진
# Study 수: 1
#   ➤ 이미지 저장됨: /4d73ceac-0c2a1cd6-1789f2a0-39077260-b2eb148d.jpg
#
# [환자 이름] 최경진
# Study 수: 1
#   ➤ 이미지 저장됨: /04f1149e-c29c04f9-340bd907-3e7c39b0-42329f91.jpg
#
# [환자 이름] 윤서준
# Study 수: 1
#   ➤ 이미지 저장됨: /44e1a4aa-fc8c03f1-9da0c06c-ea67a93a-c40490d1.jpg
#
# [환자 이름] 이호우
# Study 수: 1
#   ➤ 이미지 저장됨: /c9851dab-d94705cc-a0a26c36-a6433280-d38fa747.jpg
#
# [환자 이름] 김선준
# Study 수: 1
#   ➤ 이미지 저장됨: /1267c81b-0e0ba9b6-7e7c10ea-9b5caf18-f501d3cf.jpg
#
# [환자 이름] 김성영
# Study 수: 1
#   ➤ 이미지 저장됨: /49434938-e016c0e6-2933c9e6-f2ea9179-c10c56e7.jpg
#
# [환자 이름] 임태준
# Study 수: 1
#   ➤ 이미지 저장됨: /68935ad1-8ae9e12c-92646d56-1dc423da-9bd10f7d.jpg
#
# [환자 이름] 강준지
# Study 수: 1
#   ➤ 이미지 저장됨: /ac665a40-630b09a9-3ec4439e-ee3ba98d-331e0b29.jpg
#
# [환자 이름] 장준재
# Study 수: 1
#   ➤ 이미지 저장됨: /367df5b9-a81901c7-1555e1ce-b7b0fdcd-99e0bf6e.jpg
#
# [환자 이름] 임우윤
# Study 수: 1
#   ➤ 이미지 저장됨: /ea63a6ac-da7515f6-a20d6a77-90f42032-eb303458.jpg
#
# [환자 이름] 박수진
# Study 수: 1
#   ➤ 이미지 저장됨: /2f6fc241-e514aac1-4cc86e69-31210821-b13623e4.jpg
#
# [환자 이름] 윤서태
# Study 수: 1
#   ➤ 이미지 저장됨: /53e53326-07384d5e-c92323e4-ec79b7a4-8fd9ca18.jpg
#
# [환자 이름] 김민민
# Study 수: 1
#   ➤ 이미지 저장됨: /78312c92-e79b8858-89749fae-c38b661a-f1215203.jpg
#
# [환자 이름] 김현우
# Study 수: 1
#   ➤ 이미지 저장됨: /fb254ecb-517fe66b-72afdcf2-57dba68a-22a3a133.jpg
#
# [환자 이름] 장선하
# Study 수: 1
#   ➤ 이미지 저장됨: /240a9c47-a873c5af-6e9a1093-e7a9da83-c2f7de1c.jpg
#
# [환자 이름] 김경서
# Study 수: 1
#   ➤ 이미지 저장됨: /5b02d0f9-b0c83491-8a3eb835-0d8397f3-f314d173.jpg
#
# [환자 이름] 강하현
# Study 수: 1
#   ➤ 이미지 저장됨: /78ed92b7-c29f5985-2dd5d5cd-2b8c6123-fb595bdb.jpg
#
# [환자 이름] 이호윤
# Study 수: 1
#   ➤ 이미지 저장됨: /8271ffb2-525c8446-f9045d50-0bccbbec-5eb6a59b.jpg
#
# [환자 이름] 김서도
# Study 수: 1
#   ➤ 이미지 저장됨: /04cad845-e92d4c2c-086c6817-24412d93-c3aad73d.jpg
#
# [환자 이름] 윤하하
# Study 수: 1
#   ➤ 이미지 저장됨: /f11387e7-456a8ad5-489a4138-a53647d3-49c7d6bb.jpg
#
# [환자 이름] 조태준
# Study 수: 1
#   ➤ 이미지 저장됨: /f5a53337-05c81ee0-7cb59e91-e2d3a8fa-6b157da4.jpg
#
# [환자 이름] 윤진호
# Study 수: 1
#   ➤ 이미지 저장됨: /90c816e3-8dfdc5d6-a9b6e796-5bfa10ab-8233542a.jpg
#
# [환자 이름] 임우하
# Study 수: 1
#   ➤ 이미지 저장됨: /bb062c7e-01d2e305-220eb0ca-55b241fd-946a1d7c.jpg
#
# [환자 이름] 장재재
# Study 수: 1
#   ➤ 이미지 저장됨: /9146cf19-145d8cb6-1e5a01fe-50125e53-5a0a6f95.jpg
#
# [환자 이름] 김하준
# Study 수: 1
#   ➤ 이미지 저장됨: /64705510-0ef2542b-0d1239f0-6a9ee2fc-570ae39b.jpg
#
# [환자 이름] 장호민
# Study 수: 1
#   ➤ 이미지 저장됨: /8de69dea-43d2f738-dbd22eaa-a4534886-66b6bf26.jpg
#
# [환자 이름] 박호윤
# Study 수: 1
#   ➤ 이미지 저장됨: /46bebc5b-397225cd-5f92d521-ead0cc12-8f0c6de3.jpg
#
# [환자 이름] 김경성
# Study 수: 1
#   ➤ 이미지 저장됨: /b7f3ec1f-b13e3211-97bbec21-f68ef2c5-7ec9884e.jpg
#
# [환자 이름] 장준도
# Study 수: 1
#   ➤ 이미지 저장됨: /e6fda53e-a3f86cfa-04a3ce42-798c2a2b-4d081786.jpg
#
# [환자 이름] 임태지
# Study 수: 1
#   ➤ 이미지 저장됨: /9a63364a-67ff64e0-8c28f6d6-b35e6562-9092f3ac.jpg
#
# [환자 이름] 최선민
# Study 수: 1
#   ➤ 이미지 저장됨: /b3683855-e4a81104-5a7ce9c0-44035b81-b832bd11.jpg
#
# [환자 이름] 강서호
# Study 수: 1
#   ➤ 이미지 저장됨: /c7b5fd12-b8847820-343da4f3-75634d03-f58e4d54.jpg
#
# [환자 이름] 강서재
# Study 수: 1
#   ➤ 이미지 저장됨: /0d6919c8-6d7cfbfe-cec4ab64-5993d503-b5751fc9.jpg
#
# [환자 이름] 강태성
# Study 수: 1
#   ➤ 이미지 저장됨: /d3c57fa2-c705e98b-eed6b225-c0089647-a5865c0e.jpg
#
# [환자 이름] 최지영
# Study 수: 1
#   ➤ 이미지 저장됨: /9bd825d6-82c8c168-4c26a851-552ebea7-5295e83b.jpg
#
# [환자 이름] 김성민
# Study 수: 1
#   ➤ 이미지 저장됨: /f2a49e73-8479c4f4-2838ea0c-6e808a4a-5d952c29.jpg
#
# [환자 이름] 강재수
# Study 수: 1
#   ➤ 이미지 저장됨: /74a727f8-ecc62780-fa433057-e1498f28-748713ff.jpg
#
# [환자 이름] 임우지
# Study 수: 1
#   ➤ 이미지 저장됨: /b438465a-0d805ebc-36f57bf2-a6b6e9f1-76438546.jpg
#
# [환자 이름] 윤준서
# Study 수: 1
#   ➤ 이미지 저장됨: /4fd096bc-d1d0644a-d93710d3-fdb055a4-4afdc42f.jpg
#
# [환자 이름] 정호현
# Study 수: 1
#   ➤ 이미지 저장됨: /87429c1b-463733eb-ad6a1252-8e17829e-ecbb0645.jpg
#
# [환자 이름] 강지하
# Study 수: 1
#   ➤ 이미지 저장됨: /b4386d43-86696db8-e9b1ce18-25d36069-f6b35d75.jpg
#
# [환자 이름] 김경민
# Study 수: 1
#   ➤ 이미지 저장됨: /deabb062-558cd4ee-0c9710c1-fab78e3a-96378226.jpg
#
# [환자 이름] 임경민
# Study 수: 1
#   ➤ 이미지 저장됨: /1b900352-7221cb4f-ca3e489a-83ed5930-906a166f.jpg
#
# [환자 이름] 최서호
# Study 수: 1
#   ➤ 이미지 저장됨: /bf26e5fc-a0fea092-fa516180-58b0a8d6-6d3e5a3c.jpg
#
# [환자 이름] 장하수
# Study 수: 1
#   ➤ 이미지 저장됨: /728b642a-6b805144-6acd96c2-b0c13d27-f7321958.jpg
#
# [환자 이름] 이현현
# Study 수: 1
#   ➤ 이미지 저장됨: /09127bb8-d8b90418-7fd741b8-7b0afe5d-340fd6f0.jpg
#
# [환자 이름] 강선도
# Study 수: 1
#   ➤ 이미지 저장됨: /f4c5a5e3-cff2ba72-7b6f1a75-bc2224f0-8edc51d8.jpg
#
# [환자 이름] 이윤진
# Study 수: 1
#   ➤ 이미지 저장됨: /8efe20c1-b25aa68a-0e355255-c50eb392-5d589a6d.jpg
#
# [환자 이름] 정영서
# Study 수: 1
#   ➤ 이미지 저장됨: /2d1beb8e-b925aeee-79b81a55-072b6a7e-f3e33800.jpg
#
# [환자 이름] 조우진
# Study 수: 1
#   ➤ 이미지 저장됨: /4356dd1d-a7d0e01a-d0d3a9b6-50f3f614-157c3177.jpg
#
# [환자 이름] 최영호
# Study 수: 1
#   ➤ 이미지 저장됨: /b3869deb-7a516e26-f8ff8bf0-16965c23-b8fb0ba0.jpg
#
# [환자 이름] 장준현
# Study 수: 1
#   ➤ 이미지 저장됨: /925a6f0d-c72534b0-50f32a0d-8962459d-cc69ec22.jpg
#
# [환자 이름] 박준하
# Study 수: 1
#   ➤ 이미지 저장됨: /b2de0c95-b0816bca-d3582953-a0a9bb12-59bc774b.jpg
#
# [환자 이름] 최재호
# Study 수: 1
#   ➤ 이미지 저장됨: /c85cca01-b4019d42-e5502976-2c62032f-6626ce75.jpg
#
# [환자 이름] 장민수
# Study 수: 1
#   ➤ 이미지 저장됨: /05ad20ed-35972b2b-18c211b4-4b6f6038-3599f9db.jpg
#
# [환자 이름] 조하호
# Study 수: 1
#   ➤ 이미지 저장됨: /1660b71e-f769d7e8-131c07a0-e466ae4e-43566244.jpg
#
# [환자 이름] 정태현
# Study 수: 1
#   ➤ 이미지 저장됨: /d533b029-393db8f4-8c8a2a6c-74840ddc-4d8ec3d9.jpg
#
# [환자 이름] 장수재
# Study 수: 1
#   ➤ 이미지 저장됨: /de2fe183-90830469-8507ab06-8dbaeb88-419dff5d.jpg
#
# [환자 이름] 임성선
# Study 수: 1
#   ➤ 이미지 저장됨: /5664f1bc-f596b8fd-b5c075fa-2599a0eb-9cc75690.jpg
#
# [환자 이름] 윤호영
# Study 수: 1
#   ➤ 이미지 저장됨: /237aa899-e51eb137-1722135c-c6b7bf21-0ac2dc29.jpg
#
# [환자 이름] 최성경
# Study 수: 1
#   ➤ 이미지 저장됨: /0ff001cc-54c493f3-ad823fd5-83ae0d2e-8a182daf.jpg
#
# [환자 이름] 박경진
# Study 수: 1
#   ➤ 이미지 저장됨: /9e6df082-e052a939-72bd0274-af68f867-2bfa88ce.jpg
#
# [환자 이름] 임경우
# Study 수: 1
#   ➤ 이미지 저장됨: /f5458a20-802081b6-966b0157-75847ac8-8103524d.jpg
#
# [환자 이름] 박호하
# Study 수: 1
#   ➤ 이미지 저장됨: /58e98981-69439675-b127265b-261f6249-36742971.jpg
#
# [환자 이름] 박호경
# Study 수: 1
#   ➤ 이미지 저장됨: /9a53c485-e715a1e4-60beeb6e-c8ff4c55-22cc7195.jpg
#
# [환자 이름] 정도하
# Study 수: 1
#   ➤ 이미지 저장됨: /b39ec05f-9170d00f-5da19e7b-73634cc3-adfeda1c.jpg
#
# [환자 이름] 최민태
# Study 수: 1
#   ➤ 이미지 저장됨: /981c47b9-43f34f1a-a78e1a88-2546c98b-64b0d7b4.jpg
#
# [환자 이름] 정영민
# Study 수: 1
#   ➤ 이미지 저장됨: /0ad4a66b-329175dc-54192595-5e2d664a-e0fb3778.jpg
#
# [환자 이름] 김성우
# Study 수: 1
#   ➤ 이미지 저장됨: /38ba31cb-a578d6ce-0ef938be-43043e2a-8e102ddc.jpg
#
# [환자 이름] 이수서
# Study 수: 1
#   ➤ 이미지 저장됨: /76e34304-0100df37-2c88689f-0e6653d4-12e2198a.jpg
#
# [환자 이름] 박윤현
# Study 수: 1
#   ➤ 이미지 저장됨: /9bb1ca1c-a3776c58-f2dcaf11-4471ba05-682c0231.jpg
#
# [환자 이름] 장하서
# Study 수: 1
#   ➤ 이미지 저장됨: /043db086-1d18ff57-aba740c5-0eeced99-0de85a36.jpg
#
# [환자 이름] 강도지
# Study 수: 1
#   ➤ 이미지 저장됨: /e4571f4c-83b0d454-be2e8380-b4ecf4f0-3300fb1a.jpg
#
# [환자 이름] 장민진
# Study 수: 1
#   ➤ 이미지 저장됨: /ee050331-71014a73-3381da0c-129388e7-5abf4172.jpg
#
# [환자 이름] 김하서
# Study 수: 1
#   ➤ 이미지 저장됨: /c7e8ac41-d2b81413-a433570e-2c01f987-30560093.jpg
#
# [환자 이름] 김선지
# Study 수: 1
#   ➤ 이미지 저장됨: /2bbe58e7-37309900-8fe939b3-bb4f735c-413514b0.jpg
#
# [환자 이름] 김민지
# Study 수: 1
#   ➤ 이미지 저장됨: /f6b64a67-6a7b95d4-81801e5a-00784619-fa5f64d2.jpg
#
# [환자 이름] 정호성
# Study 수: 1
#   ➤ 이미지 저장됨: /3bfa39b9-93f6b51f-9e34ca73-0ee1c4e7-0813b683.jpg
#
# [환자 이름] 김태재
# Study 수: 1
#   ➤ 이미지 저장됨: /1be42694-99041e35-cdeb46c7-774a1151-59412599.jpg
#
# [환자 이름] 박우영
# Study 수: 1
#   ➤ 이미지 저장됨: /d0ca3214-d2fd44b3-18cf1afe-e19a7f1c-6cc6f807.jpg
#
# [환자 이름] 임호진
# Study 수: 1
#   ➤ 이미지 저장됨: /7379ccb9-d8e25ac3-b45330e4-84324ec6-767c2a45.jpg
#
# [환자 이름] 박선민
# Study 수: 1
#   ➤ 이미지 저장됨: /10ebf4f7-9be75c5e-cfba279e-47482582-266dc6a7.jpg
#
# [환자 이름] 임호영
# Study 수: 1
#   ➤ 이미지 저장됨: /2cac8d69-2b4db084-232414a2-018a8c26-dd282033.jpg
#
# [환자 이름] 이재하
# Study 수: 1
#   ➤ 이미지 저장됨: /57c22884-a040d1e7-8cc40bd7-015d96e0-ae2a0dc7.jpg
#
# [환자 이름] 조수우
# Study 수: 1
#   ➤ 이미지 저장됨: /32c8cf7b-a60e66cf-13cf01b5-fbd585d2-eedd3470.jpg
#
# [환자 이름] 윤민우
# Study 수: 1
#   ➤ 이미지 저장됨: /2169657e-e19eb9ca-ba5d9970-4f50cdd1-bebe7c54.jpg
#
# [환자 이름] 이현태
# Study 수: 1
#   ➤ 이미지 저장됨: /6a0f7b3d-9b7da822-972bf96e-13a529f3-991774a6.jpg
#
# [환자 이름] 조도영
# Study 수: 1
#   ➤ 이미지 저장됨: /928fab2a-28aab132-d4740b63-5a363f58-5350145b.jpg
#
# [환자 이름] 강준태
# Study 수: 1
#   ➤ 이미지 저장됨: /0f706282-4f311084-bda7440d-09c0b197-9c442789.jpg
#
# [환자 이름] 강호호
# Study 수: 1
#   ➤ 이미지 저장됨: /c08b6229-ccd9565e-c6d4aca1-0d00f7d1-df27624e.jpg
#
# [환자 이름] 장우도
# Study 수: 1
#   ➤ 이미지 저장됨: /d493e54b-16bdd8cf-4a7c25b1-45f3cc22-60f931a9.jpg
#
# [환자 이름] 임영윤
# Study 수: 1
#   ➤ 이미지 저장됨: /0dd54e6a-90fb467a-f67fe7c7-886d9675-ba7632fa.jpg
#
# [환자 이름] 정하하
# Study 수: 1
#   ➤ 이미지 저장됨: /2deadfa0-7372654f-78f2f1d3-4696bddf-01f04544.jpg
#
# [환자 이름] 장성선
# Study 수: 1
#   ➤ 이미지 저장됨: /51369384-9e2546a8-5fb1cf43-4cc77161-afcda4f7.jpg
#
# [환자 이름] 김윤영
# Study 수: 1
#   ➤ 이미지 저장됨: /4bebd7ad-bac12edf-4c2a000d-d38fe44d-3a009e6e.jpg
#
# [환자 이름] 윤서재
# Study 수: 1
#   ➤ 이미지 저장됨: /a60e8279-feda158f-b4b74de4-7b1276a0-9e1ab821.jpg
#
# [환자 이름] 임서호
# Study 수: 1
#   ➤ 이미지 저장됨: /2298e9fc-9a06d023-2bd9d136-ae00c718-cde4debe.jpg
#
# [환자 이름] 윤민호
# Study 수: 1
#   ➤ 이미지 저장됨: /f9eca79f-1a32568b-b12f995d-a46490c0-b6a2c6c2.jpg
#
# [환자 이름] 최재경
# Study 수: 1
#   ➤ 이미지 저장됨: /474ef34f-6919409a-7110a395-4034ad68-9e238ee1.jpg
#
# [환자 이름] 윤경준
# Study 수: 1
#   ➤ 이미지 저장됨: /d9691144-07bc303a-64c197c1-4f91aada-88a18b6a.jpg
#
# [환자 이름] 김선민
# Study 수: 1
#   ➤ 이미지 저장됨: /a5f1e38d-760e44d1-f0ec1dc1-fa947700-096b7297.jpg
#
# [환자 이름] 강하영
# Study 수: 1
#   ➤ 이미지 저장됨: /4a71f417-1bd87404-d1853318-482b7815-66638dbc.jpg
#
# [환자 이름] 김영우
# Study 수: 1
#   ➤ 이미지 저장됨: /cf4733cf-3556e0ef-154f470d-98ffad1d-588f7e6a.jpg
#
# [환자 이름] 장준진
# Study 수: 1
#   ➤ 이미지 저장됨: /d69105f0-41e4db7f-5c71aad6-8e1e655e-ac04e958.jpg
#
# [환자 이름] 장재호
# Study 수: 1
#   ➤ 이미지 저장됨: /4a8e1450-d8eec1fa-61460933-58911586-0be7bc71.jpg
#
# [환자 이름] 강경성
# Study 수: 1
#   ➤ 이미지 저장됨: /b55cef14-954f19c9-3aca4ead-611763a4-fe5da6bd.jpg
#
# [환자 이름] 정하우
# Study 수: 1
#   ➤ 이미지 저장됨: /e4ecbe5a-370e54ef-95d25315-9dc14547-51a1ee1b.jpg
#
# [환자 이름] 윤우현
# Study 수: 1
#   ➤ 이미지 저장됨: /6d5e4ae1-5a428d07-d1b22ff3-ff3d4469-416fef1c.jpg
#
# [환자 이름] 박민민
# Study 수: 1
#   ➤ 이미지 저장됨: /d457cd00-4b748611-4cb96287-1454e8a1-eb5224a9.jpg
#
# [환자 이름] 윤수우
# Study 수: 1
#   ➤ 이미지 저장됨: /77c55f6a-eb46bdf3-3f98bab4-2ff8a456-7fe660ca.jpg
#
# [환자 이름] 김수태
# Study 수: 1
#   ➤ 이미지 저장됨: /7af4ce92-e176c8b7-e99d3658-bdebedcf-472c9229.jpg
#
# [환자 이름] 장도우
# Study 수: 1
#   ➤ 이미지 저장됨: /dd34988b-402af779-2bacae28-c6293226-543477e8.jpg
#
# [환자 이름] 박하재
# Study 수: 1
#   ➤ 이미지 저장됨: /ee344e01-9a94dc01-0f648411-d2dbba27-f16eb52d.jpg
#
# [환자 이름] 장재경
# Study 수: 1
#   ➤ 이미지 저장됨: /b2ad7c4e-3dde9b8f-b0f14a1f-76a47dbc-e8b1b635.jpg
#
# [환자 이름] 박윤성
# Study 수: 1
#   ➤ 이미지 저장됨: /d2d95e69-daea45ea-3b06fca2-676a9e06-f27d2ad5.jpg
#
# [환자 이름] 최경서
# Study 수: 1
#   ➤ 이미지 저장됨: /becf6fd0-fe519d8d-eb38280f-2c728d3a-df89d9ec.jpg
#
# [환자 이름] 장수하
# Study 수: 1
#   ➤ 이미지 저장됨: /0acddae9-c49ee49d-8ead2378-e0db33a9-d09cdd63.jpg
#
# [환자 이름] 임태재
# Study 수: 1
#   ➤ 이미지 저장됨: /ebda3733-e2990040-03cef905-7c9a4433-574feb8c.jpg
#
# [환자 이름] 김태준
# Study 수: 1
#   ➤ 이미지 저장됨: /e66e7038-27903c1a-e779df1e-67765b64-c5825e8d.jpg
#
# [환자 이름] 정현도
# Study 수: 1
#   ➤ 이미지 저장됨: /5f43a798-586dcfdb-d888cca7-bbf9ce41-dbad6f9a.jpg
#
# [환자 이름] 조진성
# Study 수: 1
#   ➤ 이미지 저장됨: /2eba0c65-ca484cf2-98a7623c-f88fd3cc-fc3d12d5.jpg
#
# [환자 이름] 장호선
# Study 수: 1
#   ➤ 이미지 저장됨: /6116877b-20906f14-f56e2e6b-fd802f32-0a43d36d.jpg
#
# [환자 이름] 이호도
# Study 수: 1
#   ➤ 이미지 저장됨: /6aa98955-da51f6b1-d03ecc19-7f272c23-7f66eea0.jpg
#
# [환자 이름] 윤우진
# Study 수: 1
#   ➤ 이미지 저장됨: /8e47858f-d2046497-3ffc29c5-c29445ae-5e72a4ae.jpg
#
# [환자 이름] 강지성
# Study 수: 1
#   ➤ 이미지 저장됨: /4fe0f65e-563410c8-64908dce-aef06376-136537c2.jpg
#
# [환자 이름] 박우선
# Study 수: 1
#   ➤ 이미지 저장됨: /ba0ba154-df9dda56-8dac5bd3-6137e867-26079fa9.jpg
#
# [환자 이름] 임준하
# Study 수: 1
#   ➤ 이미지 저장됨: /dbcc7c22-6d65cce8-1e459c85-3059faa6-9cce628b.jpg
#
# [환자 이름] 김지서
# Study 수: 1
#   ➤ 이미지 저장됨: /cbb15b09-03f98f79-2a615df6-c5cf9bfc-c943d83f.jpg
#
# [환자 이름] 윤하준
# Study 수: 1
#   ➤ 이미지 저장됨: /d5d901b2-b3fc7f9a-6ce3766e-7ee7a496-56981f22.jpg
#
# [환자 이름] 임태도
# Study 수: 1
#   ➤ 이미지 저장됨: /94ea9490-46d37089-5d330886-f2ca42e2-dddb6635.jpg
#
# [환자 이름] 강윤영
# Study 수: 1
#   ➤ 이미지 저장됨: /5f380c8c-c6997696-812c4464-08e61fb4-6380d4ef.jpg
#
# [환자 이름] 정하민
# Study 수: 1
#   ➤ 이미지 저장됨: /5f6ec9fd-942da1d9-29083ee7-19b18025-47ae1a1b.jpg
#
# [환자 이름] 정영지
# Study 수: 1
#   ➤ 이미지 저장됨: /4cdbb3e6-2b008c75-9b590b3e-901d0ca1-0c0ed055.jpg
#
# [환자 이름] 임우민
# Study 수: 1
#   ➤ 이미지 저장됨: /fef3bac3-96ebe986-bd567194-f2e529a6-ebf6600c.jpg
#
# [환자 이름] 김영현
# Study 수: 1
#   ➤ 이미지 저장됨: /746cd6e1-ccba83d3-1192c8f9-a1361f92-1c50bceb.jpg
#
# [환자 이름] 강성서
# Study 수: 1
#   ➤ 이미지 저장됨: /189f01b3-20eab778-fd2ef971-7417332d-b46e355b.jpg
#
# [환자 이름] 임경준
# Study 수: 1
#   ➤ 이미지 저장됨: /3f35f9ba-f5db2e2d-b8cd1d1d-fa6b167c-a55344d1.jpg
#
# [환자 이름] 강태하
# Study 수: 1
#   ➤ 이미지 저장됨: /29fb2a30-3c23a0fe-25508881-04547fe1-9bda0a71.jpg
#
# [환자 이름] 이민재
# Study 수: 1
#   ➤ 이미지 저장됨: /0a79fd2d-e831ba3b-1f5f8c54-f9842018-9524b46e.jpg
#
# [환자 이름] 이민우
# Study 수: 1
#   ➤ 이미지 저장됨: /24ec5cd9-dd4bb61d-2c827b30-3754d109-0ed03a57.jpg
#
# [환자 이름] 정하경
# Study 수: 1
#   ➤ 이미지 저장됨: /a08c56b5-c15708c6-cf530a57-ceec78ba-0cbb649b.jpg
#
# [환자 이름] 김민수
# Study 수: 1
#   ➤ 이미지 저장됨: /8730d610-f908c317-5036d75f-7ca33366-1e6f9466.jpg
#
# [환자 이름] 윤호진
# Study 수: 1
#   ➤ 이미지 저장됨: /6aae3e36-b5c87676-e178447f-306cdb01-78bb83e1.jpg
#
# [환자 이름] 장호성
# Study 수: 1
#   ➤ 이미지 저장됨: /ed3bc13b-cacb285b-3b6e35c0-5c579941-94eb763a.jpg
#
# [환자 이름] 김우성
# Study 수: 1
#   ➤ 이미지 저장됨: /bffed8b8-94b7ef0c-5b01ce80-b294088c-56a193bd.jpg
#
# [환자 이름] 조선수
# Study 수: 1
#   ➤ 이미지 저장됨: /898c555c-dd10c290-116a6451-e9835b6f-cb497f0b.jpg
#
# [환자 이름] 조수준
# Study 수: 1
#   ➤ 이미지 저장됨: /567d2a2f-9e3dba76-5fb40e85-3ddb97e2-8eccba85.jpg
#
# [환자 이름] 최호경
# Study 수: 1
#   ➤ 이미지 저장됨: /710e032a-f9935715-906b6af9-93bc5156-8469f990.jpg
#
# [환자 이름] 이호수
# Study 수: 1
#   ➤ 이미지 저장됨: /7b8e5ed3-0a43c0be-94bfc7f3-c59f2c13-e5264396.jpg
#
# [환자 이름] 장윤수
# Study 수: 1
#   ➤ 이미지 저장됨: /288de278-8850cfc6-5554ac6e-89f025ff-f340592c.jpg
#
# [환자 이름] 최윤준
# Study 수: 1
#   ➤ 이미지 저장됨: /bc624e4e-548750e6-d10d4d15-65ad0e86-db76f2c8.jpg
#
# [환자 이름] 장성민
# Study 수: 1
#   ➤ 이미지 저장됨: /766821e6-f9263a85-fa8d8509-53a40795-abec0b14.jpg
#
# [환자 이름] 이경재
# Study 수: 1
#   ➤ 이미지 저장됨: /924217d4-9d5a10f2-a8688343-ae542ccf-1b4ce40e.jpg
#
# [환자 이름] 윤성재
# Study 수: 1
#   ➤ 이미지 저장됨: /5b246cb6-e57a5101-8e915d94-1ce1818f-0ff812c5.jpg
#
# [환자 이름] 강하윤
# Study 수: 1
#   ➤ 이미지 저장됨: /a2f80b37-3d08c544-b76d5dba-7a4ab309-98e8b16f.jpg
#
# [환자 이름] 임윤민
# Study 수: 1
#   ➤ 이미지 저장됨: /08dc835c-74a3b691-5ea98eec-07f114c5-b2b61204.jpg
#
# [환자 이름] 조호호
# Study 수: 1
#   ➤ 이미지 저장됨: /a6a62a2c-9e261e56-fce9b56d-63773ca1-2ea90ee3.jpg
#
# [환자 이름] 장준영
# Study 수: 1
#   ➤ 이미지 저장됨: /239d31ea-3b7cb11e-25491f63-9b114cbb-b3c0044e.jpg
#
# [환자 이름] 정선영
# Study 수: 1
#   ➤ 이미지 저장됨: /a85c719c-7bc9e31d-7c007d11-964da546-707d0e2c.jpg
#
# [환자 이름] 이윤현
# Study 수: 1
#   ➤ 이미지 저장됨: /ee75c33c-684fe0db-52a6f789-d8e99563-1ff8d5ae.jpg
#
# [환자 이름] 최수수
# Study 수: 1
#   ➤ 이미지 저장됨: /d75be48b-b0ae1ba0-2a5dd3a2-6e8af776-23d7ad6d.jpg
#
# [환자 이름] 장영영
# Study 수: 1
#   ➤ 이미지 저장됨: /723492bc-a20ab4e8-c73c7999-777567c6-4490e9e1.jpg
#
# [환자 이름] 이도경
# Study 수: 1
#   ➤ 이미지 저장됨: /29f7f7bc-3a2148ee-e1cd6886-a29294bc-eb93d60a.jpg
#
# [환자 이름] 김영도
# Study 수: 1
#   ➤ 이미지 저장됨: /8c028ec4-471ec7de-56a5437b-602f55a7-0c0140a7.jpg
#
# [환자 이름] 최준윤
# Study 수: 1
#   ➤ 이미지 저장됨: /af2f7e32-05f91956-5fc8a5d9-8edc5de5-6d06753d.jpg
#
# [환자 이름] 임지하
# Study 수: 1
#   ➤ 이미지 저장됨: /09344184-f1b3a7d1-db4b1020-d2ff0353-0439d4f9.jpg
#
# [환자 이름] 장경우
# Study 수: 1
#   ➤ 이미지 저장됨: /6dd8d1e1-5b8488a9-46ca6648-05160f4a-69c281fa.jpg
#
# [환자 이름] 조현영
# Study 수: 1
#   ➤ 이미지 저장됨: /d8e34103-63d29c02-70597fd6-bcb744cc-4a6423c1.jpg
#
# [환자 이름] 윤재서
# Study 수: 1
#   ➤ 이미지 저장됨: /6eeebe68-03ebd8d5-6288221a-3ec32e3e-7f4c4c58.jpg
#
# [환자 이름] 이선선
# Study 수: 1
#   ➤ 이미지 저장됨: /c1b9b338-30a5632f-c82f87e5-edc226e2-91b3410b.jpg
#
# [환자 이름] 임서준
# Study 수: 1
#   ➤ 이미지 저장됨: /f81a9a4b-abc890f5-3f84e960-39f3c223-21ee91da.jpg
#
# [환자 이름] 장우성
# Study 수: 1
#   ➤ 이미지 저장됨: /ab090c76-43480d6c-dea49b5f-427e549c-06f8b10c.jpg
#
# [환자 이름] 최호수
# Study 수: 1
#   ➤ 이미지 저장됨: /e001c31e-8ebbdd7d-d2d393b2-520b30ed-38f24b44.jpg
#
# [환자 이름] 박호진
# Study 수: 1
#   ➤ 이미지 저장됨: /355819c6-c2b3a8d2-1e8a8139-e26ced90-20312926.jpg
#
# [환자 이름] 김진재
# Study 수: 1
#   ➤ 이미지 저장됨: /66a21195-9ae7fcea-586930e4-ab5f8c99-8297fd75.jpg
#
# [환자 이름] 윤태준
# Study 수: 1
#   ➤ 이미지 저장됨: /b508ddea-677a64fd-a838437c-9e830714-73ea63d5.jpg
#
# [환자 이름] 장윤경
# Study 수: 1
#   ➤ 이미지 저장됨: /8fb6c499-7d21fad5-cba1e45c-9873483c-54cae315.jpg
#
# [환자 이름] 장윤하
# Study 수: 1
#   ➤ 이미지 저장됨: /2e2356a9-54dad343-35a68e77-ea2e8a17-5a7676fa.jpg
#
# [환자 이름] 최준재
# Study 수: 1
#   ➤ 이미지 저장됨: /be04810e-c596b16a-4d115cd6-76b04d0e-904ea506.jpg
#
# [환자 이름] 김도민
# Study 수: 1
#   ➤ 이미지 저장됨: /030a0e31-cf657c8f-61e2b268-1f39e5d2-999475ce.jpg
#
# [환자 이름] 박윤영
# Study 수: 1
#   ➤ 이미지 저장됨: /7c591f64-dca6eafe-7780c553-5f1d1562-98e7566b.jpg
#
# [환자 이름] 임태진
# Study 수: 1
#   ➤ 이미지 저장됨: /792f505a-12142a0c-e08b810f-3ce2dc60-a1985c2b.jpg
#
# [환자 이름] 조민선
# Study 수: 1
#   ➤ 이미지 저장됨: /ef47a8f5-5e5ec6f5-22ee82f9-88000336-7755f566.jpg
#
# [환자 이름] 박호영
# Study 수: 1
#   ➤ 이미지 저장됨: /0182f742-fc963659-41fa5382-40ae5bf9-56d23547.jpg
#
# [환자 이름] 최태재
# Study 수: 1
#   ➤ 이미지 저장됨: /24a24802-d293fd21-f5878fa7-b85d704c-5a633e5d.jpg
#
# [환자 이름] 이태도
# Study 수: 1
#   ➤ 이미지 저장됨: /f9abb5bb-db63acca-e88d6af7-05ed7277-02809951.jpg
#
# [환자 이름] 강서태
# Study 수: 1
#   ➤ 이미지 저장됨: /d2c08b34-204edade-8572a561-e9372e2b-e13e7aa9.jpg
#
# [환자 이름] 임민진
# Study 수: 1
#   ➤ 이미지 저장됨: /14e6a0b2-5ab214c3-e1274184-50269b15-009d37e2.jpg
#
# [환자 이름] 정선지
# Study 수: 1
#   ➤ 이미지 저장됨: /f38ea97a-8ac5710c-5aa1a223-8036f110-eff3de78.jpg
#
# [환자 이름] 이경호
# Study 수: 1
#   ➤ 이미지 저장됨: /574f93af-3b04bf41-f01e2ddb-efcb9283-69972690.jpg
#
# [환자 이름] 임수민
# Study 수: 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 35
#      32 for instance_id in series_info['Instances']:
#      33     # 이미지 썸네일 가져오기 (예시)
#      34     preview_url = f"{ORTHANC_URL}/instances/{instance_id}/preview"
# ---> 35     image = requests.get(preview_url, auth=AUTH).content
#      37     # 저장해보기
#      38     with open(f"DICOM_GET/{instance_id}.jpg", "wb") as f:
#
# File c:\Users\hyssk\anaconda3\envs\MedicalProject\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\hyssk\anaconda3\envs\MedicalProject\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\hyssk\anaconda3\envs\MedicalProject\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\hyssk\anaconda3\envs\MedicalProject\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\hyssk\anaconda3\envs\MedicalProject\lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File c:\Users\hyssk\anaconda3\envs\MedicalProject\lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File c:\Users\hyssk\anaconda3\envs\MedicalProject\lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\hyssk\anaconda3\envs\MedicalProject\lib\site-packages\urllib3\connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File c:\Users\hyssk\anaconda3\envs\MedicalProject\lib\http\client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File c:\Users\hyssk\anaconda3\envs\MedicalProject\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File c:\Users\hyssk\anaconda3\envs\MedicalProject\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File c:\Users\hyssk\anaconda3\envs\MedicalProject\lib\socket.py:717, in SocketIO.readinto(self, b)
#     715 while True:
#     716     try:
# --> 717         return self._sock.recv_into(b)
#     718     except timeout:
#     719         self._timeout_occurred = True
#
# KeyboardInterrupt:
